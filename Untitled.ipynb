# %% [markdown]
# <a href="https://colab.research.google.com/github/abhakose/Ai_Learnings-with-Krishan-kumar/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
print(tf.test.gpu_device_name())
# Out:
# /device:GPU:0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2c0c3568-c2df-49d8-ad62-4b41db11576a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c0c3568-c2df-49d8-ad62-4b41db11576a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset = pd.read_csv('Churn_Modelling.csv')

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
X = dataset.iloc[:,:-1]

# %%
X.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary
# 0        101348.88
# 1        112542.58
# 2        113931.57
# 3         93826.63
# 4         79084.10

# %%
Y = dataset.iloc[:,-1]

# %%
Y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
X= dataset.iloc[:,3:13]

# %%
X.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
X['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
Geography =pd.get_dummies(X['Geography'],drop_first=True)

# %%
Gender = pd.get_dummies(X['Gender'],drop_first=True)

# %%
X=X.drop(['Geography','Gender'],axis=1)

# %%
X.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary
# 0               1        101348.88
# 1               1        112542.58
# 2               0        113931.57
# 3               0         93826.63
# 4               1         79084.10

# %%
X =pd.concat([X,Geography,Gender],axis=1)

# %%
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0                  1        101348.88        0      0     0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sd =StandardScaler()

# %%
X_train = sd.fit_transform(X_train)
X_test = sd.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-1.19119591, -0.94312892, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ..., -0.5698444 ,
#         -0.57369368,  0.91601335],
#        [-0.62420521, -0.08179119,  1.39076231, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  1.75486502,
#         -0.57369368, -1.09168714]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import ReLU,PReLU,LeakyReLU,ELU
from tensorflow.keras.layers import Dropout

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units=11,activation='relu'))

# %%
classifier.add(Dense(units=7,activation="relu"))

# %%
classifier.add(Dense(units=6,activation='relu'))

# %%
classifier.add(Dense(1,activation='sigmoid'))

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model_history = classifier.fit(X_train,Y_train,validation_split=0.33,batch_size=10,epochs=50)
# Out:
# Epoch 1/50
# 536/536 [==============================] - 6s 5ms/step - loss: 0.5268 - accuracy: 0.7710 - val_loss: 0.4472 - val_accuracy: 0.8073
# Epoch 2/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4283 - accuracy: 0.8151 - val_loss: 0.4303 - val_accuracy: 0.8111
# Epoch 3/50
# 536/536 [==============================] - 3s 5ms/step - loss: 0.4155 - accuracy: 0.8218 - val_loss: 0.4261 - val_accuracy: 0.8076
# Epoch 4/50
# 536/536 [==============================] - 3s 5ms/step - loss: 0.4094 - accuracy: 0.8270 - val_loss: 0.4184 - val_accuracy: 0.8186
# Epoch 5/50
# 536/536 [==============================] - 3s 6ms/step - loss: 0.4041 - accuracy: 0.8276 - val_loss: 0.4149 - val_accuracy: 0.8209
# Epoch 6/50
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3985 - accuracy: 0.8309 - val_loss: 0.4131 - val_accuracy: 0.8209
# Epoch 7/50
# ...

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
y_pred= classifier.predict(X_test)
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %%
y_pred=(y_pred>0.5)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,y_pred)
# Out:
# array([[1506,   89],
#        [ 194,  211]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,Y_test)
# Out:
# 0.8585
